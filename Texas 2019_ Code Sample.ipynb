# %% [markdown]
# ## Plot Data for Census Data

# %%
import pandas as pd
import requests
import re
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
Drug_2019 = pd.read_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\2019_Texas\drug_search_2019.csv")

# %%
General_2019 = pd.read_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\2019_Texas\combined2.csv")
# Out:
# C:\Users\orteg\AppData\Local\Temp\ipykernel_35640\2300612237.py:1: DtypeWarning: Columns (3,11,20,23,29,42,45,46,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   General_2019 = pd.read_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\2019_Texas\combined2.csv")

# %% [markdown]
# ## Clean Data

# %%
selected_columns = ['Month', 'Violation_Code', 'Driver_Race_Sex', 'Datetime', 'County', 'Road_Location', 'Latitude', 'Longitude', 'Contraband_Drugs_Found']

# %%
Clean_19 = Drug_2019[selected_columns].copy()

# %%
Clean_19['Month'] = Clean_19['Month'].str.replace('_19', '')

# %%
Clean_19['Month'] = Clean_19['Month'].str.replace('_2019', '')

# %%
Clean_19['Driver_Race_Sex'].replace('Black Male', 'Black', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('Black Female', 'Black', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('Hispanic or Latino Male', 'Hispanic or Latino', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('Hispanic or Latino Female', 'Hispanic or Latino', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('White Male', 'White', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('White Female', 'White', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('Asian or Pacific Islander Male', 'Asian or Pacific Islander', inplace=True)

# %%
Clean_19['Driver_Race_Sex'].replace('Asian or Pacific Islander Female', 'Asian or Pacific Islander', inplace=True)

# %%
Clean_19.to_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Clean_2019.csv")

# %%
month_counts = Clean_19['Month'].value_counts()

# Sort the months in ascending order of the count
sorted_months = month_counts.sort_values(ascending=True)

# Plot the bar chart
plt.bar(sorted_months.index, sorted_months)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts of Times Drugs Were Found in 2019')

# Add the total count as a text annotation
total_count = sorted_months.sum()
plt.text(0.02, 0.95, f'Total Count: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top')

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA")

# %% [markdown]
# ## Get NaN
# These are the places in 2019 that do not have a lat and long for the points people were stopped on certain roads. The MP stand for Mileposts- WILL TRY TO FIND

# %%
Clean_19.rename(columns={'Driver_Race_Sex':'Race'}, inplace=True)

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_colwidth', None)

# Create a boolean mask for rows with NaN values in 'Latitude' or 'Longitude'
latitude_nan = pd.isna(Clean_19['Latitude'])
longitude_nan = pd.isna(Clean_19['Longitude'])
nan_rows = Clean_19[latitude_nan | longitude_nan]

# Print the rows where 'Latitude' or 'Longitude' is NaN

# %%
nan_rows.to_csv = r'C:\Users\orteg\OneDrive\Desktop\Data_RA\NaN_2019.csv'

# %%
month_2 = nan_rows['Month'].value_counts()

# Sort the months in ascending order of the count
sorted_2 = month_2.sort_values(ascending=True)

# Plot the bar chart
plt.bar(sorted_2.index, sorted_2)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts of NaN in 2019')

# Add the total count as a text annotation
total_count = sorted_2.sum()
plt.text(0.02, 0.95, f'Total Count: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top')

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Nan_count_2019_bar.png")

# %% [markdown]
# ## Plot Traffic Count 2019

# %%
selected = ['Month', 'Violation_Code', 'Driver_Race_Sex', 'Datetime', 'Race_Known_Prior', 'County', 'Latitude', 'Longitude', 'Contraband_Drugs_Found']
new_19 = General_2019[selected].copy()

# %%
new_19.rename(columns={'Driver_Race_Sex':'Race'}, inplace=True)

# %%
new_19['Race'].replace('Asian or Pacific Islander Female', 'Asian or Pacific Islander', inplace=True)

# %%
new_19['Race'].replace('Asian or Pacific Islander Male', 'Asian or Pacific Islander', inplace=True)

# %%
new_19['Race'].replace('Black Male', 'Black', inplace=True)

# %%
new_19['Race'].replace('Black Female', 'Black', inplace=True)

# %%
new_19['Race'].replace('Hispanic or Latino Male', 'Hispanic or Latino', inplace=True)

# %%
new_19['Race'].replace('Hispanic or Latino Female', 'Hispanic or Latino', inplace=True)

# %%
new_19['Race'].replace('White Male', 'White', inplace=True)

# %%
new_19['Race'].replace('White Female', 'White', inplace=True)

# %%
new_19.to_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Clean_2019.csv")

# %%
import matplotlib.pyplot as plt

# %%
month = new_19['Month'].value_counts()

# Sort the months in ascending order of the count
sorted_month = month.sort_values(ascending=True)

# Plot the bar chart
plt.bar(sorted_month.index, sorted_month)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts of Traffic Stops in 2019')

# Add the total count as a text annotation
total_count = sorted_month.sum()
plt.text(0.02, 0.95, f'Total Count: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top')

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA)

# %% [markdown]
# ## Plot in order of months

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Ap', 'May', 'June', 'July', 'August', 'Sept', 'Oct', 'Nov', 'Dec']

# Get the counts of each unique month
month_counts = new_19['Month'].value_counts()

# Reindex the month_counts Series to match the specified order
month_counts = month_counts.reindex(month_order)

# Plot the bar chart
plt.bar(month_counts.index, month_counts)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts of Traffic Stops in 2019')

# Add the total count as a text annotation
total_count = month_counts.sum()
plt.text(0.03, 1, f'Total Count: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot in order of months - bigger plot

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Ap', 'May', 'June', 'July', 'August', 'Sept', 'Oct', 'Nov', 'Dec']

month_counts = new_19['Month'].value_counts()

# Reindex the month_counts Series to match the specified order
month_counts = month_counts.reindex(month_order)

# Set the figure size to make the entire plot larger
plt.figure(figsize=(10, 6))

# Plot the bar chart
plt.bar(month_counts.index, month_counts)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts of Traffic Stops in 2019')

# Add the total count as a text annotation with a bigger box
total_count = month_counts.sum()
plt.text(0.02, 0.97, f'Total Count 2019: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', facecolor='white'))

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\traffic_count_inorder_bar_19.png")

# %% [markdown]
# ## Missing Counties

# %%
Missing = nan_rows
Missing
# Out:
#       Month  Violation_Code                Race             Datetime  \
# 5       Apr           104.0               White  2019-04-17 07:00:00
# 9       Apr           107.0               White  2019-04-17 07:00:00
# 18      Apr          1404.0  Hispanic or Latino  2019-04-19 00:30:00
# 20      Apr          1404.0  Hispanic or Latino  2019-04-21 14:51:00
# 33      Apr          1905.0               Black  2019-04-11 14:26:00
# ...     ...             ...                 ...                  ...
# 40155   Mar          4716.0               Black        3/6/2019 9:11
# 40156   Mar          5403.0               Black        3/6/2019 9:11
# 40157   Mar         42001.0               Black        3/6/2019 9:11
# 40158   Mar         42001.0               Black        3/6/2019 9:11
# 40159   Mar         42002.0               Black        3/6/2019 9:11
#
#            County                          Road_Location  Latitude  Longitude  \
# ...

# %%
Missing.to_csv = r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA"

# %%
#collin_latitude = 33.1987288
#collin_longitude = -96.8163888

# Set the latitude and longitude values for all rows where "Collin" is found in the "County" column
#clean_20.loc[clean_20['name'] == 'Collin', 'Latitude'] = collin_latitude
#clean_20.loc[clean_20['name'] == 'Collin', 'Longitude'] = collin_longitude

# %%
# Check for NaN values in the "Latitude" column
#latitude_nan = clean_20['Latitude'].isna()

# Check for NaN values in the "Longitude" column
#longitude_nan = clean_20['Longitude'].isnull()

# %%
#combined_nan_rows = clean_20[latitude_nan | longitude_nan]
#combined_nan_rows
# Out:
#         Month  Violation_Code            Driver_Race_Sex             Datetime  \
# 16        Jan           103.0                      White  2020-01-21 20:45:00
# 26        Jan           103.0                      Black  2020-01-02 11:58:00
# 29        Jan           103.0         Hispanic or Latino  2020-01-28 09:39:00
# 32        Jan           103.0         Hispanic or Latino  2020-01-03 19:29:00
# 43        Jan           103.0                      Black  2020-01-03 17:55:00
# ...       ...             ...                        ...                  ...
# 2704008   Dec          7219.0  Asian or Pacific Islander  2020-12-31 21:56:00
# 2704009   Dec          6221.0  Asian or Pacific Islander  2020-12-31 21:56:00
# 2704010   Dec          6222.0  Asian or Pacific Islander  2020-12-31 21:56:00
# 2704011   Dec          6220.0  Asian or Pacific Islander  2020-12-31 21:56:00
# 2704012   Dec          2706.0  Asian or Pacific Islander  2020-12-31 21:56:00
#
# ...

# %% [markdown]
# ## Get Census Data

# %%
from shapely.geometry import Point

# %%
census = pd.read_csv (r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Census_Shapefile_2019.csv")

# %%
column_to_drop = ['Unnamed: 0', 'geometry', 'SHAPE_Leng', 'SHAPE_Area', 'GlobalID']
df = census.drop(columns=column_to_drop)

# %%
df['FIPS'] = df['FIPS'].astype(int)

# %%
shapefile_path = r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\counties\Counties.shp"

# Load the shapefile into a GeoDataFrame
gdf = gpd.read_file(shapefile_path)

# Print the GeoDataFrame
gdf
# Out:
#     FIPS  CNTYKEY    FENAME  COLOR    Shape_area      Shape_len  \
# 0    001        1  ANDERSON      2  2.780466e+09  373745.841489
# 1    003        2   ANDREWS      4  3.872734e+09  256976.117572
# 2    005        3  ANGELINA      3  2.230237e+09  344349.841497
# 3    007        4   ARANSAS      4  1.365529e+09  200974.380757
# 4    009        5    ARCHER      3  2.391373e+09  195629.480337
# ..   ...      ...       ...    ...           ...            ...
# 249  499      250      WOOD      3  1.795629e+09  228476.416290
# 250  501      251    YOAKUM      1  2.064951e+09  181902.545341
# 251  503      252     YOUNG      4  2.403549e+09  196418.972905
# 252  505      253    ZAPATA      2  2.742975e+09  238439.458742
# 253  507      254    ZAVALA      5  3.362606e+09  235281.862989
#
#                                               geometry
# 0    POLYGON ((1430817.289 1110458.449, 1430870.389...
# 1    POLYGON ((718610.781 1153890.815, 718656.265 1...
# ...

# %%
gdf['FIPS'] = '48' + gdf['FIPS'].astype(str)

# %%
gdf['FIPS'] = gdf['FIPS'].astype(int)

# %%
merged_19 = df.merge(gdf, on= 'FIPS', how='right')

# %%
merged_19
# Out:
#        County  Total:     White alone     Black or African American alone  \
# 0    Anderson     NaN             NaN                                 NaN
# 1         NaN     NaN             NaN                                 NaN
# 2    Angelina  86,715          71,060                              13,419
# 3     Aransas     NaN             NaN                                 NaN
# 4         NaN     NaN             NaN                                 NaN
# ..        ...     ...             ...                                 ...
# 249      Wood  45,539          40,469                               1,404
# 250       NaN     NaN             NaN                                 NaN
# 251       NaN     NaN             NaN                                 NaN
# 252       NaN     NaN             NaN                                 NaN
# 253       NaN     NaN             NaN                                 NaN
#
#         American Indian and Alaska Native alone     Asian alone  \
# ...

# %%
geo
# Out:
#        County  Total:     White alone     Black or African American alone  \
# 0    Anderson     NaN             NaN                                 NaN
# 1         NaN     NaN             NaN                                 NaN
# 2    Angelina  86,715          71,060                              13,419
# 3     Aransas     NaN             NaN                                 NaN
# 4         NaN     NaN             NaN                                 NaN
# ..        ...     ...             ...                                 ...
# 249      Wood  45,539          40,469                               1,404
# 250       NaN     NaN             NaN                                 NaN
# 251       NaN     NaN             NaN                                 NaN
# 252       NaN     NaN             NaN                                 NaN
# 253       NaN     NaN             NaN                                 NaN
#
#         American Indian and Alaska Native alone     Asian alone  \
# ...

# %%
geo.to_csv = r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Census_Info_2019.csv"

# %%
import geopandas as gpd

# Assuming 'geo' is your GeoDataFrame
geo.to_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Census_Info_2019.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35640\4034500586.py in <cell line: 4>()
#       2
#       3 # Assuming 'geo' is your GeoDataFrame
# ----> 4 geo.to_csv(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Census_Info_2019.csv", index=False)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### Count of Null and Non-Null Values for Census

# %%
# Filter rows with NaN values in the 'county' column
gdf_missing_county = geo[geo['Total:'].isnull()]

# Plot the GeoDataFrame with non-NaN values in one color
fig, ax = plt.subplots(figsize=(12, 10))  # Adjust the figsize here to make the plot bigger
geo[geo['Total:'].notnull()].plot(ax=ax, color='brown', label='Non-NaN Points')

# Plot the filtered GeoDataFrame with NaN values in the 'county' column in red
gdf_missing_county.plot(ax=ax, color='orange', marker='x', markersize=100, label='NaN County Points')

# Add a legend
ax.legend()

# Display the plot
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\missing_totalcensus_info_19.png")
# Out:
# C:\Users\orteg\AppData\Local\Temp\ipykernel_35640\3386604757.py:12: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Count the number of counties that are null (NaN) in the 'County' column
count_null_counties = geo['Total:'].isnull().sum()

# Count the number of counties that are not null in the 'County' column
count_valid_counties = geo['Total:'].notnull().sum()

# Print the results
print("Number of counties with null values:", count_null_counties)
print("Number of counties without null values:", count_valid_counties)
# Out:
# Number of counties with null values: 171
# Number of counties without null values: 83

# %% [markdown]
# ## School Data

# %%
from shapely.geometry import Point

# %%
# %matplotlib inline

# Assuming your data is in a DataFrame called 'table' with columns 'Latitude' and 'Longitude'

# Create a geometry column of Point objects
geometry = [Point(xy) for xy in zip(Clean_19['Longitude'], Clean_19['Latitude'])]

# Create a GeoDataFrame
Clean_19 = gpd.GeoDataFrame(Clean_19, geometry=geometry)

# Plot the GeoDataFrame
ax = Clean_19.plot(marker='o', color='red', markersize=5)

# Display the plot
plt.show()

# %%
from arcgis.gis import GIS
gis = GIS('pro')
print("logged in as " + str(gis.properties.user.username))
# Out:
# logged in as ogo698_Harvard_CGA

# %%
school = gis.content.get("675cd244e150480ea725747ceb4579dc")
school
# Out:
# <Item title:"Schools 2022 to 2023" type:Feature Layer Collection owner:GISAdmin_TEA_Texas>

# %%
school_layer = school.layers[0]  # Assuming the schoolpoints item is a feature layer the command takes out the first layer in the set
zone = school_layer.query()  # Retrieve all features
table3 = zone.sdf  # Convert the feature set to a pandas DataFrame
(table3)
# Out:
#       ObjectID Status  Score Match_type  \
# 0            1      M  100.0          A
# 1            2      M  100.0          A
# 2            3      M  100.0          A
# 3            4      M  100.0          A
# 4            5      M  100.0          A
# ...        ...    ...    ...        ...
# 9716      9717      M  97.75          A
# 9717      9718      M  100.0          A
# 9718      9719      M  100.0          A
# 9719      9720      M  100.0         PP
# 9720      9721      M  98.35          A
#
#                                              Match_addr  \
# 0     17750 N US Highway 287, Tennessee Colony, Texa...
# 1     17750 N US Highway 287, Tennessee Colony, Texa...
# 2          420 W Palestine Ave, Palestine, Texas, 75801
# 3     17750 N US Highway 287, Tennessee Colony, Texa...
# 4                301 E Parker St, Elkhart, Texas, 75839
# ...                                                 ...
# 9716        909 Javalina Dr, Crystal City, Texas, 78839
# ...

# %%
table3.to_csv = r'C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Texas_schools.csv'

# %%
school_gdf = gpd.GeoDataFrame(table3, geometry='SHAPE')

# %%
school_gdf
# Out:
#       ObjectID Status  Score Match_type  \
# 0            1      M  100.0          A
# 1            2      M  100.0          A
# 2            3      M  100.0          A
# 3            4      M  100.0          A
# 4            5      M  100.0          A
# ...        ...    ...    ...        ...
# 9716      9717      M  97.75          A
# 9717      9718      M  100.0          A
# 9718      9719      M  100.0          A
# 9719      9720      M  100.0         PP
# 9720      9721      M  98.35          A
#
#                                              Match_addr  \
# 0     17750 N US Highway 287, Tennessee Colony, Texa...
# 1     17750 N US Highway 287, Tennessee Colony, Texa...
# 2          420 W Palestine Ave, Palestine, Texas, 75801
# 3     17750 N US Highway 287, Tennessee Colony, Texa...
# 4                301 E Parker St, Elkhart, Texas, 75839
# ...                                                 ...
# 9716        909 Javalina Dr, Crystal City, Texas, 78839
# ...

# %% [markdown]
# ## CRS Setting

# %%
school_gdf.crs = {"init": "epsg:4269"}
school_gdf = school_gdf.to_crs({"init": "epsg:2163"})
# Out:
# C:\Users\orteg\AppData\Roaming\Python\Python39\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
geo = geo.to_crs({"init": "epsg:2163"})

# %%
Clean_19.crs = {"init": "epsg:4269"}
Drug_search_2019 = Clean_19.to_crs({"init": "epsg:2163"})

# %%
fig, ax = plt.subplots(1,1,figsize=(10,10),dpi=100)

geo.plot(ax=ax)
school_gdf.plot(ax=ax, color ='red')

plt.show()

# %%
# Filter rows with NaN values in the 'county' column
gdf_missing_county = geo[geo['Total:'].isnull()]

# Plot the GeoDataFrame with non-NaN values in one color
fig, ax = plt.subplots(figsize=(12, 10))
geo[geo['Total:'].notnull()].plot(ax=ax, color='brown', label='Non-NaN Points')

# Plot the filtered GeoDataFrame with NaN values in the 'county' column in red
gdf_missing_county.plot(ax=ax, color='orange', marker='x', markersize=100, label='NaN County Points')

# Plot school_gdf with a different color and reduced marker size (e.g., 5)
school_gdf.plot(ax=ax, color='blue', label='School Points', markersize=8)

# Plot drug_gdf with a different color
Drug_search_2019.plot(ax=ax, color='green', label='Drug Points', markersize=5)

# Add a legend
ax.legend()

# Display the plot
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Work and Internship Documents\Data_RA\Map_Drugsearch_19.png")
# Out:
# C:\Users\orteg\AppData\Local\Temp\ipykernel_35640\3493554005.py:20: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()

# %% [markdown]
# ### Set Up Buffer

# %%
school_gdf['buffered'] = school_gdf.buffer(1000)

# %%
# Filter rows with NaN values in the 'county' column
gdf_missing_county = geo[geo['Total:'].isnull()]

# Plot the GeoDataFrame with non-NaN values in one color
fig, ax = plt.subplots(figsize=(12, 10))
geo[geo['Total:'].notnull()].plot(ax=ax, color='brown', label='Non-NaN Points')

# Plot the filtered GeoDataFrame with NaN values in the 'county' column in red
gdf_missing_county.plot(ax=ax, color='orange', marker='x', markersize=100, label='NaN County Points')

# Plot school_gdf with a different color and reduced marker size (e.g., 5)
school_gdf.plot(ax=ax, color='blue', label='School Points', markersize=8)
school_gdf["buffered"].plot(alpha=0.2, ax=ax, color='yellow')

# Find the drug points that fall within the buffer
drug_within_buffer = Drug_search_2019[Drug_search_2019.geometry.within(school_gdf["buffered"].unary_union)]

# Plot drug_within_buffer with a different color
drug_within_buffer.plot(ax=ax, color='green', label='Drug Points Within Buffer', markersize=5)

# Add a legend
ax.legend()

# Display the plot
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\map_drugpoints_within_buffer_19.png")
# Out:
# C:\Users\orteg\AppData\Roaming\Python\Python39\site-packages\shapely\predicates.py:946: RuntimeWarning: invalid value encountered in within
#   return lib.within(a, b, **kwargs)
# C:\Users\orteg\AppData\Local\Temp\ipykernel_35640\3990244021.py:22: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35640\3990244021.py in <cell line: 26>()
#      24 # Display the plot
#      25 plt.show()
# ---> 26 plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\map_drugpoints_within_buffer_19.png")
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
# ...

# %%
drug_within_buffer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35640\1126842640.py in <cell line: 1>()
# ----> 1 drug_within_buffer
#
# NameError: name 'drug_within_buffer' is not defined

# %%
drug_within_buffer.to_csv = r'C:\Users\orteg\OneDrive\Desktop\Data_RA\within_school_buffer_19.csv'

# %%
month = drug_within_buffer['Month'].value_counts()

# Sort the months in ascending order of the count
sorted_month = month.sort_values(ascending=True)

# Plot the bar chart
plt.bar(sorted_month.index, sorted_month)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts Within 1000 Feet of School Buffer in 2019')

# Add the total count as a text annotation
total_count = sorted_month.sum()
plt.text(0.02, 0.95, f'Total Count: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top')

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\drugstop_within_buffer_2019.png")

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'Jun', 'Jul', 'Aug', 'Dec']

month_counts = drug_within_buffer['Month'].value_counts()

# Reindex the month_counts Series to match the specified order
month_counts = month_counts.reindex(month_order)

# Set the figure size to make the entire plot larger
plt.figure(figsize=(10, 6))

# Plot the bar chart
plt.bar(month_counts.index, month_counts)

# Label the bars with the corresponding month
plt.xticks(rotation=45, ha='right')
plt.xlabel('Month')
plt.ylabel('Counts')
plt.title('Counts of Drug Stops in Buffer 2019')

# Add the total count as a text annotation with a bigger box
total_count = month_counts.sum()
plt.text(0.02, 0.97, f'Total Count 2019: {total_count}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', facecolor='white'))

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\total_buffer_2019.png")

# %%
pivot_table = drug_within_buffer.pivot_table(index='Race', columns='Month', aggfunc='size', fill_value=0)

# Reorder the columns to match the month_order
pivot_table = pivot_table[month_order]

# %%
# Set the figure size with more height to accommodate the additional space
plt.figure(figsize=(10, 8))

# Plot each race as a line graph with more space for the legend
for race in pivot_table.index:
    plt.plot(pivot_table.columns, pivot_table.loc[race], label=race, linewidth=2)

# Label the x-axis with the corresponding month
plt.xticks(rotation=45, ha='right', fontsize=12)  # Increase the font size for better readability
plt.xlabel('Month', fontsize=14)  # Increase the font size for better readability
plt.ylabel('Counts', fontsize=14)  # Increase the font size for better readability
plt.title('Drug Stops in 2019 by Race', fontsize=16)  # Increase the font size for better readability

# Add more space for the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\race_within_buffer_19.png")

# %%
total_counts_by_race = pivot_table.sum(axis=1)

# Display the total count for each race
for race, total_count_race in total_counts_by_race.items():
    print(f'Total {race}: {total_count_race}')

# The above loop will print the total count for each race. If you want to store it in a separate DataFrame:
total_counts_df = pd.DataFrame({'Race': total_counts_by_race.index, 'Total Count': total_counts_by_race.values})
total_counts_df
# Out:
# Total Alaska Native or American Indian Male: 7
# Total Asian or Pacific Islander: 53
# Total Black: 3132
# Total Hispanic or Latino: 4454
# Total White: 3003
#                                     Race  Total Count
# 0  Alaska Native or American Indian Male            7
# 1              Asian or Pacific Islander           53
# 2                                  Black         3132
# 3                     Hispanic or Latino         4454
# 4                                  White         3003

# %% [markdown]
# ## Counties with drug stops happening within buffer

# %%
pivot_table_2 = drug_within_buffer.pivot_table(index='Race', columns='County', aggfunc='size', fill_value=0)

# %%
# Plot a horizontal bar chart for the total count of Black population across counties
plt.figure(figsize=(20, 25))  # Set the figure size for better visualization
plt.barh(pivot_table_2.columns, pivot_table_2.loc['Black'], color='b', alpha=0.8)

# Label the y-axis with county names
plt.ylabel('County', fontsize=18)

# Label the x-axis
plt.xlabel('Counts', fontsize=18)

# Set the plot title
plt.title('Total Count of Black Population by County', fontsize=16)


# Add the total count for the 'Black' race as a label in the plot
total_count_black = pivot_table_2.loc['Black'].sum()
plt.text(0.05, 0.9, f'Total Black: {total_count_black}', transform=plt.gca().transAxes,
         fontsize=14, bbox=dict(boxstyle='round,pad=0.5', facecolor='white'))

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\black_within_buffer_19.png")

# %%
# Plot a horizontal bar chart for the total count of Black population across counties
plt.figure(figsize=(20, 25))  # Set the figure size for better visualization
plt.barh(pivot_table_2.columns, pivot_table_2.loc['White'], color='b', alpha=0.8)

# Label the y-axis with county names
plt.ylabel('County', fontsize=18)

# Label the x-axis
plt.xlabel('Counts', fontsize=18)

# Set the plot title
plt.title('Total Count of White Population by County', fontsize=16)


# Add the total count for the 'Black' race as a label in the plot
total_count_black = pivot_table_2.loc['White'].sum()
plt.text(0.05, 0.9, f'Total White: {total_count_black}', transform=plt.gca().transAxes,
         fontsize=14, bbox=dict(boxstyle='round,pad=0.5', facecolor='white'))

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\white_within_buffer_19.png")

# %%
# Plot a horizontal bar chart for the total count of Black population across counties
plt.figure(figsize=(20, 25))  # Set the figure size for better visualization
plt.barh(pivot_table_2.columns, pivot_table_2.loc['Hispanic or Latino'], color='b', alpha=0.8)

# Label the y-axis with county names
plt.ylabel('County', fontsize=18)

# Label the x-axis
plt.xlabel('Counts', fontsize=18)

# Set the plot title
plt.title('Total Count of Hispanic or Latino Population by County', fontsize=16)


# Add the total count for the 'Black' race as a label in the plot
total_count_black = pivot_table_2.loc['Hispanic or Latino'].sum()
plt.text(0.05, 0.7, f'Total Hispanic or Latino: {total_count_black}', transform=plt.gca().transAxes,
         fontsize=14, bbox=dict(boxstyle='round,pad=0.5', facecolor='white'))

# Show the plot
plt.tight_layout()
plt.show()
plt.savefig(r"C:\Users\orteg\OneDrive\Desktop\Data_RA\Bars\hispanic_within_buffer_19.png")

# %% [markdown]
# Hispanics and Blacks were largely arrested in drug free zones. But the gap with white people arrested is very minimal. So is another factor to consider the type of sentencing that was given to different races with drugs found in drug free zone and maybe a comparison to the people that were not found with drugs but stopped within drug free zones?
